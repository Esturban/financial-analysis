# %% [markdown]
# # Financial Modeling
#
# The purpose of this workbook is to continue the process of modeling and separate the different components of the analysis. Previously, we focused on data collection and analysis, now we will focus on model development, especially upon selecting a single instrument or equity for the analysis of technology stocks. For more information, please see the [Exploratory Data Analysis](./1_eda.ipynb) notebook

# %%
# %run ./1_eda.ipynb
# Out:
# Starting download for all stocks...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data downloaded successfully! Shape: (7530, 9)
# Columns: ['Date', 'Ticker', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'company_name']
# <class 'pandas.core.frame.DataFrame'>
# Index: 1255 entries, 0 to 1254
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1255 non-null   datetime64[ns]
#  1   Ticker        1255 non-null   object
#  2   Adj Close     1255 non-null   float64
#  3   Close         1255 non-null   float64
# ...
